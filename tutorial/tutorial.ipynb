# %%
from pyspark.sql import SparkSession

# %% [markdown]
# Data reading

# %%
df = spark.read.format("csv").option("header", True).option("inferSchema", 'true').load("/Volumes/new-test-catalog/defalut_volume/default_v1/BigMart Sales.csv")
display(df)

# %%
dbutils.fs.ls("/Volumes/new-test-catalog/defalut_volume/default_v1")

# %%
df1= spark.read.format("json")\
               .option("header",True)\
                .option("inferSchema",True)\
                .option("multiline", False)\
               .load("/Volumes/new-test-catalog/defalut_volume/default_v1/drivers.json")
display(df1)

# %%
df.printSchema()

# %% [markdown]
# DDL Schema

# %%
my_ddl_schema = '''
Item_Identifier String,
Item_Weight String,
Item_Fat_Content String,
Item_Visibility Double,
Item_Type String,
Item_MRP Double,
Outlet_Identifier String,
Outlet_Establishment_Year Integer,
Outlet_Size String,
Outlet_Location_Type String,
Outlet_Type String,
Item_Outlet_Sales Double
'''

# %%
df= spark.read.format("csv").option("header", True).schema(my_ddl_schema).load("/Volumes/new-test-catalog/defalut_volume/default_v1/BigMart Sales.csv")
display(df)

# %%
df.printSchema()

# %% [markdown]
# structtype()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
my_str_schema = StructType([
    StructField("Item_Identifier", StringType(), True),
    StructField("Item_Weight", StringType(), True),
    StructField("Item_Fat_Content", StringType(), True),
    StructField("Item_Visibility", DoubleType(), True),
    StructField("Item_Type", StringType(), True),
    StructField("Item_MRP", DoubleType(), True),
    StructField("Outlet_Identifier", StringType(), True),
    StructField("Outlet_Establishment_Year", IntegerType(), True),
    StructField("Outlet_Size", StringType(), True),
    StructField("Outlet_Location_Type", StringType(), True),
    StructField("Outlet_Type", StringType(), True),
    StructField("Item_Outlet_Sales", DoubleType(), True)
])
df= spark.read.format("csv").option("header", True).schema(my_str_schema).load("/Volumes/new-test-catalog/defalut_volume/default_v1/BigMart Sales.csv")
display(df)
df.printSchema()

# %%
df.limit(3).display()

# %%
df.select(col("Item_Identifier"),col("Item_Weight")).limit(2).display()

# %%
df.columns

# %% [markdown]
# alias

# %%
df.select(col("Item_Identifier"),col("Item_Weight").alias("Weight")).limit(2).display()

# %% [markdown]
# filter/where

# %%
df.filter(col("Item_Fat_Content") == "Regular").display()

# %%
0+9

# %%
df.filter((col("item_type") == "Soft Drinks") & (col("Item_MRP") > 100)).display()

# %%
df.filter( col("Outlet_Location_Type").isin("Tier 2","Tier 1") & col("Outlet_Size").isNull() ).display()

# %%
df.withColumnRenamed("Item_Identifier","item_code").display()

# %%
df = df.withColumnRenamed("Item_Identifier", "item_coe")\
         .withColumnRenamed("Item_Weight", "iweight")
df.display()

# %%
df.limit(2).display()

# %%
df.withColumn("new_columns",col("Item_MRP")*2).display()

# %%
df.withColumn("new_column",lit(8)).display()

# %%
df.withColumn("Item_Fat_Content", regexp_replace(col("Item_Fat_Content"), "Regular", "reg"))\
    .withColumn("Item_Fat_Content", regexp_replace(col("Item_Fat_Content"), "Low Fat", "lf")).display()

# %%
df.withColumn("iweight",col("iweight").cast("string")).display()

# %%
df.limit(2).display()

# %%
data1 = [(1,'salman'),(2,'gud')]
data2 = [(1,'salman'),(2,'gud'),(3,'shr')]
df1= spark.createDataFrame(data1,['id','name'])
df2= spark.createDataFrame(data2,['id','name'])
df1.union(df2).display()

# %%
data1 = [('salman',1),('gud',2)]
data2 = [(1,'salman'),(2,'gud'),(3,'shr')]
df1= spark.createDataFrame(data1,['name','id'])
df2= spark.createDataFrame(data2,['id','name'])
df1.unionByName(df2).display()

# %% [markdown]
# initcap(),lower(),upper()

# %%
df.limit(4).display()

# %%
df.select(initcap('Item_Type')).display()

# %%
df.select(upper('Item_Type')).display()

# %%
df.select(lower('Item_Type').alias("lower_item_type")).display()

# %%
df = df.withColumn("cur_date",current_date())

# %%
df.withColumn("cur_timestamp",current_timestamp()).display()

# %%
df = df.withColumn("after_week",col("cur_date")+7)
df.display()

# %%
df = df.withColumn("before_week",col("cur_date")-7)
df.display()

# %%
df.withColumn("before_week",date_add(current_date(),-8)).display()

# %%
from datetime import date,timedelta
date.today()
date.today()+timedelta(days= 5)

# %%
df.limit(3).display()

# %%
df.withColumn("date_diff",datediff("after_week","before_week")).display()

# %%
df.withColumn("before_week",date_format(col("before_week"),"dd-MM-yyyy")).display()

# %%
df.dropna().display()

# %%
df.limit(5).display()

# %%
df.withColumn("Outlet_Type",split("Outlet_Type"," ")).display()

# %%
df.withColumn("Outlet_Type",split("Outlet_Type"," ")[1]).display()

# %%
df1= df.withColumn("Outlet_Type",split("Outlet_Type"," "))
df1.display()

# %%
df1.withColumn("Outlet_Type",explode("Outlet_Type")).display()

# %%
df.select(day("cur_date")).display()

# %%
df1.withColumn("present",array_contains("Outlet_Type","Type1")).display()

# %%
df1.groupBy("Item_Type").sum("Item_Outlet_Sales").display()

# %%
df1.groupBy("Item_Type").agg({"Item_Outlet_Sales": "sum", "*": "count"})\
    .select("Item_Type",count(lit(1)).alias("counts"),sum("Item_Outlet_Sales").alias("sum_items"))\
    .display()

# %%
df.limit(2).display()

# %%
df = df.select("Item_Identifer","Item_Weight")

# %%
df= df.filter(col("Item_Weight") == "9.3")

# %%
df.display()

# %%
df.limit(2).display()

# %%
df.createTempView("tb1")

# %%
# %sql
df2= spark.sql("select Item_Weight from tb1")

# %%
df2 = spark.sql(
    "SELECT Item_Weight FROM tb1"
)
display(df2)
